# %% [markdown]
# Data was obtained from [Rotowire](https://www.rotowire.com/baseball/stats.php)

# %%
import pandas as pd

# %%
stats = pd.read_csv('../data/batters.csv', header=0)
display(stats.columns)

# %%
stats.groupby('Team').count()

# %%
stats.columns

# %%
stats.loc[stats['Team'] == 'ATL']
