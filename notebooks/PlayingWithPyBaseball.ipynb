# %%
from pybaseball import batting_stats_range
from datetime import datetime, timedelta
today_date = datetime.today()
two_years_ago = today_date + timedelta(-2*365)
data = batting_stats_range(str(two_years_ago.date()), str(today_date.date()))
data.head()

# %%
data.columns

# %%
acuna = data.loc[data['Name'] == 'Ronald Acuna Jr.']

# %%
acuna
